# %%
import pickle
from dataclasses asdict
from pprint import pprint

from my_music import Song

# %%
# Load the variable from the file
with open("song_list.pkl", "rb") as file:
    loaded_song_list = pickle.load(file)

print(len(loaded_song_list))
# print(loaded_song_list)
# Out:
# 1134

# %%
print(loaded_song_list)
for song in loaded_song_list.values():
    print(asdict(song))
# Out:
# {'spotify:track:51tvfFw8fHQbhCd0NJA1rR': Song(uri='spotify:track:51tvfFw8fHQbhCd0NJA1rR', name="Gipsy Kings Hit Mix '99 - Radio Mix", album='The Essential Gipsy Kings', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='2012-08-27', top_genre='flamenco', genres=['flamenco', 'rumba', 'world']), 'spotify:track:4OjJAGDDZTLlTNeOMBl7UM': Song(uri='spotify:track:4OjJAGDDZTLlTNeOMBl7UM', name='Volare (Nel Blu di Pinto di Blu)', album='Mosaïque', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='1989-05-01', top_genre='flamenco', genres=['flamenco', 'rumba', 'world']), 'spotify:track:3iB8eciGU9vZkaDYkz7Ir9': Song(uri='spotify:track:3iB8eciGU9vZkaDYkz7Ir9', name='Bamboléo', album='Gipsy Kings', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='1987-08-24', top_genre='flamenco', genres=['flamenco', 'rumba', 'world']), 'spotify:track:6VrQTLzzuyGIYjUDe4kAZk': Song(uri='spotify:track:6VrQTLzzuyGIYjUDe4kAZk', name='
# ...

# %%
import matplotlib.pyplot as plt

# Count the number of songs for each top genre
genre_counts = {}
for song in loaded_song_list.values():
    genre = song.top_genre
    if genre in genre_counts:
        genre_counts[genre] += 1
    else:
        genre_counts[genre] = 1

# Sort the genre counts in decreasing order
sorted_genre_counts = sorted(genre_counts.items(), key=lambda x: x[1], reverse=True)

# Extract the genres and counts for the bar chart
total_genres = len(sorted_genre_counts)
print(f"Total genres: {total_genres}")
bottom_limit = total_genres - 171
upper_limit = total_genres - 160
genres = [genre for genre, count in sorted_genre_counts[bottom_limit:upper_limit]]  # Limit the x axis with the first 20 elements
counts = [count for genre, count in sorted_genre_counts[bottom_limit:upper_limit]]  # Limit the x axis with the first 20 elements

# Create the bar chart
plt.bar(genres, counts)
plt.xlabel('Top Genre')
plt.ylabel('Number of Songs')
plt.title('Number of Songs per Top Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total genres: 314

# %%
# pprint(sorted_genre_counts)

# %%
def get_songs_by_top_genre(top_genre, search_words=False):
    songs = []
    if search_words:
        for song in loaded_song_list.values():
            if top_genre.lower() in song.top_genre.lower():
                songs.append(song)
    else:
        for song in loaded_song_list.values():
            if top_genre.lower() == song.top_genre.lower():
                songs.append(song)
    return songs

# %%
def get_songs_by_name(name):
    songs = []
    for song in loaded_song_list.values():
        if name.lower() in song.name.lower():
            songs.append(song)
    return songs

# %%
def get_songs_by_artist(artist):
    songs = []
    for song in loaded_song_list.values():
        for artist_list in song.artists.keys():
            if artist.lower() in artist_list.lower():
                songs.append(song)
    return songs

# %%
count_counts = {}
for genre_counts in sorted_genre_counts:
    if genre_counts[1] in count_counts:
        count_counts[genre_counts[1]] +=1
    else:
        count_counts[genre_counts[1]] = 1
# print(count_counts)

# %%
song = get_songs_by_top_genre("grunge")
pprint(song)
# Out:
# [Song(uri='spotify:track:09emSRcmA8WrhGx5MH1xon',
#       name='Dumb - 2013 Mix',
#       album='In Utero - 20th Anniversary - Deluxe Edition',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1993-09-21',
#       top_genre='grunge',
#       genres=['grunge', 'permanent wave', 'rock']),
#  Song(uri='spotify:track:0MKGH8UMfCnq5w7nG06oM5',
#       name='Come As You Are',
#       album='Nevermind (Deluxe Edition)',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1991-09-26',
#       top_genre='grunge',
#       genres=['grunge', 'permanent wave', 'rock']),
#  Song(uri='spotify:track:1f3yAtsJtY87CTmM8RLnxf',
#       name='Smells Like Teen Spirit',
#       album='Nevermind (Deluxe Edition)',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1991-09-26',
#       top_genre='grunge',
#       genres=['grunge', 'permanent wave', 'rock'])]

# %%
song = get_songs_by_top_genre("punk", search_words=True)
pprint(song)
# Out:
# [Song(uri='spotify:track:0DEJ2X4QvFGboCAdO5MyXz',
#       name='veil',
#       album='veil',
#       artists=OrderedDict([('akiaura', ['dreampunk']), ('Olya Holiday', [])]),
#       year='2022-07-15',
#       top_genre='dreampunk',
#       genres=['dreampunk']),
#  Song(uri='spotify:track:22HYEJveCvykVDHDiEEmjZ',
#       name='Tubthumping',
#       album='Tubthumper',
#       artists=OrderedDict([('Chumbawamba', ['anarcho-punk'])]),
#       year='1997-09-01',
#       top_genre='anarcho-punk',
#       genres=['anarcho-punk'])]

# %%
songs = get_songs_by_name("una noche")
pprint(songs)
# Out:
# [Song(uri='spotify:track:1O2pcBJGej0pmH2Y9XZMs6',
#       name='Una Noche en Medellín',
#       album='Una Noche en Medellín',
#       artists=OrderedDict([('Cris Mj', ['mambo chileno', 'urbano chileno'])]),
#       year='2022-01-21',
#       top_genre='mambo chileno',
#       genres=['mambo chileno', 'urbano chileno']),
#  Song(uri='spotify:track:4UioDdtVYdyTSTriYvfePU',
#       name='Una Noche',
#       album='Pequeña Orquesta de Trovadores',
#       artists=OrderedDict([('Pequeña Orquesta de Trovadores',
#                             ['argentine indie'])]),
#       year='2015-01-01',
#       top_genre='argentine indie',
#       genres=['argentine indie'])]

# %%
songs = get_songs_by_artist("strngr")
pprint(songs)
# Out:
# [Song(uri='spotify:track:3SwPwVl1M9knQgxDNAVj0z',
#       name='Departure',
#       album='TheSoundYouNeed, Vol. 3',
#       artists=OrderedDict([('Strngr', []), ('Wade', ['uk tech house'])]),
#       year='2017-11-10',
#       top_genre='uk tech house',
#       genres=['uk tech house'])]
