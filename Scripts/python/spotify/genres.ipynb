# %%
import pickle
from dataclasses import asdict
from pprint import pprint
from typing import Dict

from my_music import Song
from analysis import Analysis

# %%
mm = Analysis()

# %%
all_songs = mm.songs
print(len(all_songs))
print(all_songs)
# Out:
# 1134
# {'spotify:track:51tvfFw8fHQbhCd0NJA1rR': Song(uri='spotify:track:51tvfFw8fHQbhCd0NJA1rR', name="Gipsy Kings Hit Mix '99 - Radio Mix", album='The Essential Gipsy Kings', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='2012-08-27', top_genre='flamenco', genre='', genres=['flamenco', 'rumba', 'world']), 'spotify:track:4OjJAGDDZTLlTNeOMBl7UM': Song(uri='spotify:track:4OjJAGDDZTLlTNeOMBl7UM', name='Volare (Nel Blu di Pinto di Blu)', album='Mosaïque', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='1989-05-01', top_genre='flamenco', genre='', genres=['flamenco', 'rumba', 'world']), 'spotify:track:3iB8eciGU9vZkaDYkz7Ir9': Song(uri='spotify:track:3iB8eciGU9vZkaDYkz7Ir9', name='Bamboléo', album='Gipsy Kings', artists=OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]), year='1987-08-24', top_genre='flamenco', genre='', genres=['flamenco', 'rumba', 'world']), 'spotify:track:6VrQTLzzuyGIYjUDe4kAZk': Song(uri='spotify:track:6VrQTLzzuyGIYjUDe4kAZk', name='Un Coco', album='Un Verano Sin Ti', artists=OrderedDict([('Bad Bunny', ['reggaeton', 'trap latino', 'urbano latino'])]), year='2022-05-06', top_genre='reggaeton', genre='', genres=['reggaeton', 'trap latino', 'urbano latino']), 'spotify:track:2FlB3fJcGaohJORO93cNWv': Song(uri='spotify:track:2FlB3fJcGaohJORO93cNWv', name='SOTRS', album='Patterns Of Consciousness', artists=OrderedDict([('Caterina Barbieri', ['electra', 'experimental ambient', 'experimental synth', 'fluxwork', 'italian experimental', 'modular synth', 'spectra'])]), year='2017-05-19', top_genre='electra', genre='', genres=['electra', 'experimental ambient', 'experimental synth', 'fluxwork', 'italian experimental', 'modular synth', 'spectra']), 'spotify:track:1zi7xx7UVEFkmKfv06H8x0': Song(uri='spotify:track:1zi7xx7UVEFkmKfv06H8x0', name='One Dance', album='Views', artists=OrderedDict([('Drake', ['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap']), ('Wizkid', ['afrobeats', 'afropop', 'azonto', 'nigerian hip hop', 'nigerian pop']), ('Kyla', ['uk funky'])]), year='2016-05-06', top_genre='canadian hip hop', genre='', genres=['canadian hip hop', 'canadian pop', 'hip hop', 'pop rap', 'rap', 'afrobeats', 'afropop', 'azonto', 'nigerian hip hop', 'nigerian pop', 'uk funky']), 'spotify:track:0LP2TRYiYtwpV9qbvedm3Y': Song(uri='spotify:track:0LP2TRYiYtwpV9qbvedm3Y', name='Morning Mr Magpie', album='The King Of Limbs', artists=OrderedDict([('Radiohead', ['alternative rock', 'art rock', 'melancholia', 'oxford indie', 'permanent wave', 'rock'])]), year='2011-02-18', top_genre='alternative rock', genre='', genres=['alternative rock', 'art rock', 'melancholia', 'oxford indie', 'permanent wave', 'rock']), 'spotify:track:6kgm8RSRCeg6wblClhq8m5': Song(uri='spotify:track:6kgm8RSRCeg6wblClhq8m5', name='Honda Costumbres', album='Honda Costumbres', artists=OrderedDict([('Brunella Torpoco', ['pop peruano'])]), year='2021-12-29', top_genre='pop peruano', genre='', genres=['pop peruano']), 'spotify:track:5F1PDuoQ9ajtBnKAPVOqT4': Song(uri='spotify:track:5F1PDuoQ9ajtBnKAPVOqT4', name='The Sky Is Crying', album='Stax Profiles: Albert King', artists=OrderedDict([('Albert King', ['blues', 'blues rock', 'british blues', 'electric blues', 'memphis soul', 'soul blues', 'traditional blues'])]), year='2006-01-01', top_genre='blues', genre='', genres=['blues', 'blues rock', 'british blues', 'electric blues', 'memphis soul', 'soul blues', 'traditional blues']), 'spotify:track:601dhwn8qc31FrSlMu5wEf': Song(uri='spotify:track:601dhwn8qc31FrSlMu5wEf', name='OKI DOKI', album='MAÑANA SERÁ BONITO (BICHOTA SEASON)', artists=OrderedDict([('KAROL G', ['reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino'])]), year='2023-08-11', top_genre='reggaeton', genre='', genres=['reggaeton', 'reggaeton colombiano', 'trap latino', 'urbano latino']), 'spotify:track:4SJHHpKhcuXwDsCsPqshXj': Song(uri='spotify:track:4SJHHpKhcuXwDsCsPqshXj', name='El Efecto', album='El Efecto', artists=Ordered ...

# %%
mm.head(n=1)
# Out:
# Song 0:
# {'album': 'The Essential Gipsy Kings',
#  'artists': OrderedDict([('Gipsy Kings', ['flamenco', 'rumba', 'world'])]),
#  'genre': '',
#  'genres': ['flamenco', 'rumba', 'world'],
#  'name': "Gipsy Kings Hit Mix '99 - Radio Mix",
#  'top_genre': 'flamenco',
#  'uri': 'spotify:track:51tvfFw8fHQbhCd0NJA1rR',
#  'year': '2012-08-27'}

# %%
import matplotlib.pyplot as plt

sorted_genre_counts = mm.get_top_genre_counts()

# Extract the genres and counts for the bar chart
total_genres = len(sorted_genre_counts)
print(f"Total genres: {total_genres}")
# bottom_limit = total_genres - 171
# upper_limit = total_genres - 160
bottom_limit = 0
upper_limit = 10
genres = [genre for genre, count in sorted_genre_counts[bottom_limit:upper_limit]]  # Limit the x axis with the first 20 elements
counts = [count for genre, count in sorted_genre_counts[bottom_limit:upper_limit]]  # Limit the x axis with the first 20 elements

# Create the bar chart
plt.bar(genres, counts)
plt.xlabel('Top Genre')
plt.ylabel('Number of Songs')
plt.title('Number of Songs per Top Genre')
plt.xticks(rotation=90)
plt.show()
# Out:
# Total genres: 314

# %%
# mm.count_counts()

# %%
song = mm.get_songs_by_top_genre("grunge")
pprint(song)
# Out:
# [Song(uri='spotify:track:09emSRcmA8WrhGx5MH1xon',
#       name='Dumb - 2013 Mix',
#       album='In Utero - 20th Anniversary - Deluxe Edition',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1993-09-21',
#       top_genre='grunge',
#       genre='',
#       genres=['grunge', 'permanent wave', 'rock']),
#  Song(uri='spotify:track:0MKGH8UMfCnq5w7nG06oM5',
#       name='Come As You Are',
#       album='Nevermind (Deluxe Edition)',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1991-09-26',
#       top_genre='grunge',
#       genre='',
#       genres=['grunge', 'permanent wave', 'rock']),
#  Song(uri='spotify:track:1f3yAtsJtY87CTmM8RLnxf',
#       name='Smells Like Teen Spirit',
#       album='Nevermind (Deluxe Edition)',
#       artists=OrderedDict([('Nirvana', ['grunge', 'permanent wave', 'rock'])]),
#       year='1991-09-26',
#       top_genre='grunge',
#       genre='',
#       genres=['grunge', 'permanent wave', 'rock'])]

# %%
song = mm.get_songs_by_top_genre("punk", search_words=True)
pprint(song)
# Out:
# [Song(uri='spotify:track:0DEJ2X4QvFGboCAdO5MyXz',
#       name='veil',
#       album='veil',
#       artists=OrderedDict([('akiaura', ['dreampunk']), ('Olya Holiday', [])]),
#       year='2022-07-15',
#       top_genre='dreampunk',
#       genre='',
#       genres=['dreampunk']),
#  Song(uri='spotify:track:22HYEJveCvykVDHDiEEmjZ',
#       name='Tubthumping',
#       album='Tubthumper',
#       artists=OrderedDict([('Chumbawamba', ['anarcho-punk'])]),
#       year='1997-09-01',
#       top_genre='anarcho-punk',
#       genre='',
#       genres=['anarcho-punk'])]

# %%
songs = mm.get_songs_by_name("Loreley")
pprint(songs)
# Out:
# [Song(uri='spotify:track:5plDcIUqvmCsbc1rvJRfk1',
#       name='Loreley',
#       album='1977',
#       artists=OrderedDict([('Kölsch',
#                             ['danish electronic',
#                              'danish techno',
#                              'deep euro house',
#                              'melodic techno',
#                              'minimal techno'])]),
#       year='2013-06-24',
#       top_genre='danish electronic',
#       genre='',
#       genres=['danish electronic',
#               'danish techno',
#               'deep euro house',
#               'melodic techno',
#               'minimal techno'])]

# %%
songs = mm.get_songs_by_name("Drinkee")
pprint(songs)
# Out:
# [Song(uri='spotify:track:5TBsLU9TSxjDLzMpsEgJsv',
#       name='Drinkee',
#       album='Drinkee',
#       artists=OrderedDict([('Sofi Tukker', ['edm'])]),
#       year='2016-04-21',
#       top_genre='edm',
#       genre='',
#       genres=['edm'])]

# %%
songs = mm.get_songs_by_name("Innerbloom")
pprint(songs)
# Out:
# [Song(uri='spotify:track:0y15AkjmaFJqMpbJPbeEXF',
#       name='Innerbloom (What So Not Remix)',
#       album='Innerbloom - REMIXES',
#       artists=OrderedDict([('RÜFÜS DU SOL',
#                             ['australian electropop', 'indietronica'])]),
#       year='2016-03-18',
#       top_genre='australian electropop',
#       genre='',
#       genres=['australian electropop', 'indietronica'])]

# %%
songs = mm.get_songs_by_artist("strngr")
pprint(songs)
# Out:
# [Song(uri='spotify:track:3SwPwVl1M9knQgxDNAVj0z',
#       name='Departure',
#       album='TheSoundYouNeed, Vol. 3',
#       artists=OrderedDict([('Strngr', []), ('Wade', ['uk tech house'])]),
#       year='2017-11-10',
#       top_genre='uk tech house',
#       genre='',
#       genres=['uk tech house'])]

# %%
genres = [genre[0] for genre in sorted_genre_counts]

# %%
minimum_nb_songs = 20
selected_genres = [
    genre[0] for genre in sorted_genre_counts if genre[1] >= minimum_nb_songs
]

# %%
songs[0]
# Out:
# Song(uri='spotify:track:3SwPwVl1M9knQgxDNAVj0z', name='Departure', album='TheSoundYouNeed, Vol. 3', artists=OrderedDict([('Strngr', []), ('Wade', ['uk tech house'])]), year='2017-11-10', top_genre='uk tech house', genre='', genres=['uk tech house'])

# %%
songs = mm.get_songs_by_top_genre('edm', search_words=False)
# pprint(songs)
print(songs)
# Out:
# [Song(uri='spotify:track:1vW12BfxjOQKYElBm9ttW9', name='Billie (loving arms)', album='Actual Life 2 (February 2 - October 15 2021)', artists=OrderedDict([('Fred again..', ['edm', 'house', 'stutter house'])]), year='2021-11-19', top_genre='edm', genre='', genres=['edm', 'house', 'stutter house']), Song(uri='spotify:track:5Z8Dj3LtbyCMiwE86rhg2f', name='Marea (we’ve lost dancing)', album='Actual Life (April 14 - December 17 2020)', artists=OrderedDict([('Fred again..', ['edm', 'house', 'stutter house']), ('The Blessed Madonna', ['edm'])]), year='2021-04-15', top_genre='edm', genre='', genres=['edm', 'house', 'stutter house', 'edm']), Song(uri='spotify:track:68sV2BrAllqHBHoYhKejaT', name='PSY or DIE', album='PSY or DIE', artists=OrderedDict([('Carnage', ['edm', 'electro house', 'electronic trap', 'viral trap']), ('Timmy Trumpet', ['australian dance', 'big room', 'melbourne bounce', 'melbourne bounce international'])]), year='2016-07-18', top_genre='edm', genre='', genres=['edm', 'electro house', 'electronic trap', 'viral trap', 'australian dance', 'big room', 'melbourne bounce', 'melbourne bounce international']), Song(uri='spotify:track:5sIx4BlfYGuZeSLF40N9GH', name='Remind Me to Forget', album='Remind Me to Forget', artists=OrderedDict([('Kygo', ['edm', 'pop', 'pop dance', 'tropical house']), ('Miguel', ['r&b', 'urban contemporary'])]), year='2018-03-16', top_genre='edm', genre='', genres=['edm', 'pop', 'pop dance', 'tropical house', 'r&b', 'urban contemporary']), Song(uri='spotify:track:0lYBSQXN6rCTvUZvg9S0lU', name='Let Me Love You', album='Encore', artists=OrderedDict([('DJ Snake', ['edm', 'electronic trap', 'pop', 'pop dance']), ('Justin Bieber', ['canadian pop', 'pop'])]), year='2016-08-05', top_genre='edm', genre='', genres=['edm', 'electronic trap', 'pop', 'pop dance', 'canadian pop', 'pop']), Song(uri='spotify:track:7MiZjKawmXTsTNePyTfPyL', name='Devil Eyes', album='Providence', artists=OrderedDict([('Hippie Sabotage', ['edm', 'electronic trap'])]), year='2016-02-05', top_genre='edm', genre='', genres=['edm', 'electronic trap']), Song(uri='spotify:track:5N4erncE7kuUccm7zEmwzk', name='Electricity (with Dua Lipa)', album='Electricity (with Dua Lipa)', artists=OrderedDict([('Silk City', ['edm']), ('Dua Lipa', ['dance pop', 'pop', 'uk pop']), ('Diplo', ['edm', 'electro house', 'moombahton', 'pop dance']), ('Mark Ronson', ['pop soul'])]), year='2018-09-06', top_genre='edm', genre='', genres=['edm', 'dance pop', 'pop', 'uk pop', 'edm', 'electro house', 'moombahton', 'pop dance', 'pop soul']), Song(uri='spotify:track:0b6wdul3A5sQNpIOv03OxP', name='Ocean Drive', album='Ocean Drive', artists=OrderedDict([('Duke Dumont', ['edm', 'house', 'pop dance', 'progressive house', 'uk dance'])]), year='2015-07-31', top_genre='edm', genre='', genres=['edm', 'house', 'pop dance', 'progressive house', 'uk dance']), Song(uri='spotify:track:4BiiDQtijdt0WdtiyIPhnO', name='Magenta Riddim', album='Magenta Riddim', artists=OrderedDict([('DJ Snake', ['edm', 'electronic trap', 'pop', 'pop dance'])]), year='2018-02-23', top_genre='edm', genre='', genres=['edm', 'electronic trap', 'pop', 'pop dance']), Song(uri='spotify:track:4gCeoAADi0gWPVbwLhhuqq', name='Riverside 2099', album='Riverside 2099', artists=OrderedDict([('Oliver Heldens', ['edm', 'electro house', 'future house', 'house', 'pop dance', 'progressive electro house', 'progressive house']), ('Sidney Samson', ['dutch house', 'electro house', 'melbourne bounce', 'progressive electro house'])]), year='2018-07-06', top_genre='edm', genre='', genres=['edm', 'electro house', 'future house', 'house', 'pop dance', 'progressive electro house', 'progressive house', 'dutch house', 'electro house', 'melbourne bounce', 'progressive electro house']), Song(uri='spotify:track:4JJRH9nxxAx1wPQc6grdVz', name='Latch', album='Beach Party', artists=OrderedDict([('Disclosure', ['edm', 'house', 'indietronica', 'uk dance']), ('Sam Smith', ['pop', 'uk pop'])]), year='2019-06-28', top_genre='edm', genre='', genres=['edm', ...

# %%
len(all_songs)
# Out:
# 1134

# %%
genre_possibility_counts = mm.get_genres_counts()
# Extract the genres and counts for the bar chart
total_possibility_genres = len(genre_possibility_counts)
print(f"Total possiblity genres: {total_possibility_genres}")
# Out:
# Total possiblity genres: 779

# %%
sorted_genre_counts[:5]
# Out:
# [('urbano latino', 218),
#  ('pop', 215),
#  ('trap latino', 171),
#  ('reggaeton', 168),
#  ('rock', 154)]
