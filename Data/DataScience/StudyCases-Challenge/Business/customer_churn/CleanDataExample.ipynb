# %% [markdown]
# ### Python Pandas Counting the Occurrences of a Specific value
# https://stackoverflow.com/questions/35277075/python-pandas-counting-the-occurrences-of-a-specific-value

# %% [markdown]
# ### Python Pandas - difference between 'loc' and 'where'?
# https://stackoverflow.com/questions/54900717/python-pandas-difference-between-loc-and-where

# %% [markdown]
# ### Using loc with multiple conditions
# https://kanoki.org/2020/01/21/pandas-dataframe-filter-with-multiple-conditions/

# %% [markdown]
# ### How to use Regex in Pandas
# https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/

# %% [markdown]
# ### Test Regex
# https://regex101.com/

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("survey.csv")
num_columns = len(df.columns)
pd.set_option("display.max_columns", num_columns)
df.head(30)
# Out:
#               Timestamp  Age  Gender         Country state self_employed  \
# 0   2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1   2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2   2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3   2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4   2014-08-27 11:30:22   31    Male   United States    TX           NaN
# 5   2014-08-27 11:31:22   33    Male   United States    TN           NaN
# 6   2014-08-27 11:31:50   35  Female   United States    MI           NaN
# 7   2014-08-27 11:32:05   39       M          Canada   NaN           NaN
# 8   2014-08-27 11:32:39   42  Female   United States    IL           NaN
# 9   2014-08-27 11:32:43   23    Male          Canada   NaN           NaN
# 10  2014-08-27 11:32:44   31    Male   United States    OH           NaN
# 11  2014-08-27 11:32:49   29    male        Bulgaria   NaN           NaN
# ...

# %%
feature_names = df.columns.tolist()
feature_names.remove('Timestamp')
feature_names.remove('comments')

for column in feature_names:
    print("\n\n*************Column:*************", column)
    print(df[column].value_counts(dropna=False))
# Out:
# *************Column:************* Age
#  29             85
#  32             82
#  26             75
#  27             71
#  33             70
#  28             68
#  31             67
#  34             65
#  30             63
#  25             61
#  35             55
#  23             51
#  24             46
#  37             43
#  38             39
#  36             37
#  39             33
#  40             33
#  43             28
#  41             21
#  22             21
#  42             20
#  21             16
#  45             12
#  46             12
#  44             11
#  19              9
#  18              7
#  20              6
#  48              6
#  50              6
#  51              5
#  56              4
#  49              4
#  57              3
#  54              3
#  55              3
#  47              2
#  60              2
#  11              1
#  8               1
#  5               1
#  99999999999     1
# -1726            1
#  53              1
# ...

# %%
features = df.drop('treatment', 1)
features = features.drop('Timestamp', 1)
features = features.drop('comments', 1)
labels = df['treatment']

# %%
from sklearn.impute import SimpleImputer
#imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
#imputer = SimpleImputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
imputer = SimpleImputer(missing_values = 'NaN', strategy = 'mean')
imputer.fit(features) 
features = imputer.transform(features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-12498f684344> in <module>
#       3 #imputer = SimpleImputer(missing_values = 'NaN', strategy = 'mean', axis = 0)
#       4 imputer = SimpleImputer(missing_values = 'NaN', strategy = 'mean')
# ----> 5 imputer.fit(features)
#       6 features = imputer.transform(features)
#
# ~/DataScience/lib/python3.7/site-packages/sklearn/impute/_base.py in fit(self, X, y)
#     275         self : SimpleImputer
#     276         """
# --> 277         X = self._validate_input(X, in_fit=True)
#     278         super()._fit_indicator(X)
#     279
#
# ~/DataScience/lib/python3.7/site-packages/sklearn/impute/_base.py in _validate_input(self, X, in_fit)
#     247                 new_ve = ValueError("Cannot use {} strategy with non-numeric "
#     248                                     "data:\n{}".format(self.strategy, ve))
# ...
